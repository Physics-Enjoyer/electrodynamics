# %% [markdown]
# # Equation references
#
# Some of the equations references come from problems in the book which are not included in this version so I have included them here.

# %% [markdown]
# <!-- TODO: fill in missing Equations. So far looks like I need
# Eq. 1.108
# Eq. 5.93
# Eq. 3.105-->
